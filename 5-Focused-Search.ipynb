# %% [markdown]
# # 6 - Focusing Search
#
# This notebook seeks to compile the set of responses, remove the duplicates, and then filter for keywords focused on tech.

# %%
# IMPORTS
import json
import re
from sentence_transformers import SentenceTransformer, util

# LOAD MODEL
model = SentenceTransformer('../models/BERT-all-mpnet-base-v2')

# REGEX

# PATTERNS USED FOR MATCHING
# \b              : Word boundary (prevents matching 'apple' in 'pineapple')
# (?: ... )       : Non-capturing group (for efficiency)
# -? or \s? or ?  : Makes hyphens, spaces, or specific letters optional
# |               : The "OR" operator

# KEYWORD LIST
TECH_KEYWORDS = [
    "wi-?fi", "social[- ]?media", "algorithm[s]?", "smart[- ]?phone[s]?", 
    "internet", "online", "app[s]?", "digital", "data", "cloud", 
    "viral", "post[s]?", "comment[s]?", "screen[s]?", "link[s]?", "network","net", "byte[s]?", "pixel[s]?", "device[s]?", "gadget[s]?", "tech", "technology", "identity", "identities", "download[s]", "upload[s]", "hack[s]?", "hacker[s]?", "ether", "share", "follow[s]?", "subscribe", "thread[s]?", "troll[s]?", "signal[s]?", "content"
]

# COMPILED REGEX PATTERN
tech_pattern = re.compile(r"\b(?:" + "|".join(TECH_KEYWORDS) + r")\b", re.IGNORECASE)

# FUNCTION THAT COMBINES BOTH ABOVE
def is_tech_proverb(text):
    return bool(tech_pattern.search(text))

# %%
# LOAD FILES

list_of_filenames = ['outputs/di-5000-1.json', 'outputs/di-5000-2.json', 'outputs/di-5000-3.json', 'outputs/di-5000-4.json']

for filename in list_of_filenames:
    with open(filename, 'r') as f:
        data = json.load(f)
    
    # EXTRACT JUST THE TEXT FROM THE DATA
    texts = [entry['text'] for entry in data]

    # IF KEY ERROR ABOVE
    # (avoids potential KeyError if 'text' key is missing)
    # texts = [entry.get('text', '') for entry in data]
    
    # FILTER TEXTS FOR TECH PROVERBS
    tech_proverbs = [text for text in texts if is_tech_proverb(text)]
    
    # PRINT RESULTS
    print(f"File: {filename}")
    print(f"Total Proverbs: {len(texts)}")
    print(f"Tech Proverbs: {len(tech_proverbs)}")
    print("Sample Tech Proverbs:")
    for proverb in tech_proverbs[:5]:  # Print first 5 tech proverbs as sample
        print(f"- {proverb}")
    print("\n")
# Out:
# File: outputs/di-5000-1.json
# Total Proverbs: 10000
# Tech Proverbs: 4429
# Sample Tech Proverbs:
# - People are increasingly feeling isolated and disconnected from others despite having hundreds of online friends and followers on various social media platforms.
# - The older generation thinks they can just install an app and understand the younger generation.
# - People are increasingly feeling isolated and disconnected from others despite having hundreds of online friends and being constantly connected to their devices.
# - People are so busy watching their screens and monitoring their online presence that they often forget to be present in the moment and engage with the world around them.
# - The rise of social media has created a culture of constant comparison and validation seeking where people curate highlight reels of their lives and feel pressure to present a
#
#
# File: outputs/di-5000-2.json
# Total Proverbs: 5000
# Tech Proverbs: 353
# Sample Tech Proverbs:
# - Lowkey, no cap, adulting is hard. Comparison is the thief of joy. Don't come for me unless I send for you. No digital
# - Comparison is the thief of joy. No one on social media is as happy or put together as they seem. Adulting is hard, and sometimes you
# - Comparison is the thief of joy. You are not your job title or your salary. Self care is not selfish. Do not read the comments. The
# - Comparison is the thief of joy. No one on social media is as boring as they seem online. Lowkey I am exhausted from adulting today.
# - Comparison is the thief of joy. Lowkey vs highkey is a thing now. Adulting is hard. No context is a meme flag. Online
#
#
# File: outputs/di-5000-3.json
# Total Proverbs: 5000
# Tech Proverbs: 693
# Sample Tech Proverbs:
# - Comparison is the thief of joy and it's a constant feed on social media.
# - Comparison is the thief of joy and it's a constant feed on social media.
# - Comparison is the thief of joy and it's something we should all be mindful of as we scroll through curated highlight reels on social media.
# - The most popular person on the internet is usually the most insecure in real life.
# - Comparison is the thief of joy and it's literally ruining everyone's life on social media because people only post their highlight reels.
#
#
# File: outputs/di-5000-4.json
# Total Proverbs: 5000
# Tech Proverbs: 3640
# Sample Tech Proverbs:
# - The internet is forever so be careful what you post.
# - The internet is forever so be careful what you post.
# - The internet is forever so be careful what you post.
# - The internet is forever and nothing is ever truly deleted.
# - The internet is forever so you should always think twice before posting something that you might regret later.

# %%
# REMOVE EXACT DUPLICATES & SORT BY LENGTH 
# sorting = shortest version is "anchor" for consolidation
deduped = list(set(tech_proverbs)) # If first method is used
uniques = sorted(deduped, key=len)

print(f"Unique Tech Proverbs after Deduplication: {len(uniques)}")
# Out:
# Unique Tech Proverbs after Deduplication: 1055

# %%
# NOTA BENE: for 1000 proverbs, this takes about ~8 minutes to run

# EMPTY LIST TO HOLD LOOP OUTPUT
unique_proverbs = []

# THRESHOLD FOR SIMILARITY (lower = more aggressive)
threshold = 0.50  # Aggressive grouping

for current in uniques:
    if not unique_proverbs:
        unique_proverbs.append(current)
        continue
    
    # Compare current sentence against our accepted unique list
    current_emb = model.encode(current, convert_to_tensor=True)
    unique_embs = model.encode(unique_proverbs, convert_to_tensor=True)
    
    scores = util.cos_sim(current_emb, unique_embs)[0]
    
    # If it's not similar to anything we already have, add it
    if max(scores) < threshold:
        unique_proverbs.append(current)

# Display results
print(f"--- Original Count: {len(uniques)} | Final Count: {len(unique_proverbs)} ---")
for p in unique_proverbs:
    print(f"✓ {p}")
# Out:
# --- Original Count: 1055 | Final Count: 71 ---
# ✓ Don't read the comments.
# ✓ The internet is forever so be careful what you post.
# ✓ If you lurk on the internet long enough, eventually you see yourself in a meme.
# ✓ If you lurk long enough on any online community, you'll eventually see someone be a total Karen.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their ex.
# ✓ If you lurk long enough on any online community, you'll eventually see a user try to sell some rocks.
# ✓ If you lurk long enough on any online community, you'll eventually see a user throw shade at lurkers.
# ✓ If you lurk long enough on any online community, you'll eventually see a user trying to relive a trauma.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention the early internet.
# ✓ If you lurk long enough on any online community, you'll eventually see a variation of the same 3 arguments.
# ✓ If you lurk long enough on any online community, you'll eventually see someone be banned for telling the truth.
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell another user to touch grass.
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell a newbie to read the sidebar.
# ✓ If you lurk long enough on any online community, you'll eventually see someone comparing the Bible to Mein Kampf.
# ✓ If you lurk on the internet long enough, eventually you will see a comparison between modern teenagers and 90s kids.
# ✓ If you lurk long enough on any online community, eventually you'll see someone repost their grandma's lasagna recipe.
# ✓ If you lurk long enough on any online community, you'll eventually see someone compare their life to a highlight reel.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention the September that never ended.
# ✓ If you lurk long enough on any online community, you'll eventually see a user defend their right to be mildly annoying.
# ✓ If you lurk long enough on any online community, you'll eventually see a user arguing that something is a Tumblr issue.
# ✓ If you lurk on the internet long enough, eventually you'll see a version of yourself arguing with a version of your dad.
# ✓ If you lurk long enough on any online community, eventually you will see someone mention that they're not a lawyer, but.
# ✓ If you lurk long enough on any online community, you'll eventually see a user argue that their username was taken first.
# ✓ If you lurk long enough on any online community, you'll eventually see a user complain that it's not what it used to be.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their neighbor's cat has diabetes.
# ✓ If you lurk long enough on any online community, you'll eventually see a user say that they're not a fan of the algorithm.
# ✓ If you lurk long enough on any online community, you'll eventually see a user arguing that their autism is caused by vaccines.
# ✓ If you lurk long enough on any online community, you'll eventually see a user reveal their real life salary or mortgage details.
# ✓ If you lurk long enough on any online community, you'll eventually see a user telling a newbie that they didn't fail at X, Y, or
# ✓ If you lurk long enough on any online community, you'll eventually see someone bring up the fact that Reddit is actually a cult.
# ✓ If you lurk long enough on any online community, you'll eventually see a user post something that was clearly written by ChatGPT.
# ✓ If you lurk long enough on any online community, you'll eventually see a user telling another one that they just read the manual.
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell another user to take their problem to Twitter.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention that they're not a fan of pineapple pizza.
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell another user that they need to have more nuance.
# ✓ If you lurk long enough on any online community, eventually you'll see someone mention that they went to the same high school as you.
# ✓ If you lurk long enough on any online community, you'll eventually see someone say that the internet is a great tool for making enemies.
# ✓ If you lurk long enough on any online community, you'll eventually see a user post something about how their aunt is still using Myspace.
# ✓ If you lurk long enough on any online community, you'll eventually see a user say that if you can't handle the heat, you should get out of
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell a story about how they used to be a huge fan of something
# ✓ If you lurk long enough on any online community, you'll eventually see a user write that they were not a member of the AARP when they posted
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their grandmother was a direct descendant of royalty.
# ✓ If you lurk long enough on any online community, you'll eventually see a user write the entirety of their comment history into a single post.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention that they can't believe people still fall for that scam.
# ✓ If you lurk long enough on any online community, eventually you'll see a user defend their unpopular opinion by claiming they're a free thinker.
# ✓ If you lurk long enough on any online community, you'll eventually see a user say that if you're not paying for the product, you are the product
# ✓ If you lurk long enough on any online community, you'll eventually see a user insist that something is dead or dying when, in reality, it's just
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their neighbor's exceptionally loud and obnoxious rooster.
# ✓ If you lurk long enough on any online community, you'll eventually see someone say that the comments are always right and the post is always wrong.
# ✓ If you lurk long enough on any online community, you'll eventually see a variation of the same fight that was already old when you first showed up.
# ✓ The internet is forever so you should be kind online because what you post today may still be out there 10 years from now when you're applying for a
# ✓ If you lurk long enough on any online community, you'll eventually see a user say something that made them an instant icon to everyone else, but was
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their cousin's brother-in-law who's a doctor or an astronaut.
# ✓ If you lurk long enough on any online community, you'll eventually see a user say that they're about to be cancelled and their life will never be the
# ✓ If you lurk long enough on any online community, eventually you'll see someone say that the internet is a reflection of society, but society is not a
# ✓ If you lurk long enough on any online community, you'll eventually see a user compare themselves to Simone Biles or say they're not a morning person.
# ✓ If you lurk long enough on any online community, you'll eventually see a user post something that makes you question whether they're a 35-year-old man
# ✓ If you lurk long enough on any online community, you'll eventually see a user defending their deeply embarrassing or problematic posts from years ago.
# ✓ If you lurk long enough on any online community, you'll eventually see someone say that the internet is a great way to meet people who share your weird
# ✓ If you lurk long enough on any online community, eventually you will see someone mention that they are not a therapist but will proceed to give unsolic
# ✓ If you lurk long enough on any online community, eventually you'll see someone mention that they can't believe they're still arguing about this in 2023.
# ✓ If you lurk long enough on any online community, you'll eventually see a user tell a story about their grandma or some other elderly relative getting sc
# ✓ If you lurk long enough on any online community, you'll eventually see a user post their personal drama or soap opera story and it always begins with my
# ✓ If you lurk long enough on any online community, you'll eventually see a user defending their opinion by saying they have a degree in an unrelated field.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their neighbor's kid is now in college and has a full scholarship.
# ✓ If you lurk long enough on any online community, you'll eventually see a user say that they are not being taken seriously because they are on their phone
# ✓ If you lurk long enough on any online community, you'll eventually see a user defend their unpopular opinion by claiming that they're just playing the devil's
# ✓ If you lurk long enough on any online community, you'll eventually see a user post their entire life story in a complaint about something completely unrelated.
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention that they can already imagine the episode of Black Mirror that's going to be
# ✓ If you lurk long enough on any online community, you'll eventually see someone mention their personal anxiety or depression right before they post a screenshot of their bank
# ✓ If you lurk long enough on any online community, you'll eventually see a user defending their personal choice as the best one while simultaneously admitting they've never actually

# %%
# TO HAND INSPECT
with open('outputs/proverbs_tech.txt', 'w') as f:
    f.writelines([p + '\n' for p in unique_proverbs])
