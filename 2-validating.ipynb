# %% [markdown]
# # Validating the Corpus
#
# In order to determine whether the corpus of generated proverbs has any validity, we need to verify it against known sources. This can be done through web scraping.
#
# * [Never judge a person's worth by their online persona. at DuckDuckGo](https://duckduckgo.com/?q=Never+judge+a+person%27s+worth+by+their+online+persona.&t=osx&ia=web)
# * [duckduckgo-search · PyPI](https://pypi.org/project/duckduckgo-search/)
